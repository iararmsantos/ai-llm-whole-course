# %% [markdown]
# ## RAG Day 3
#
# ### Expert Question Answerer for InsureLLM
#
# LangChain 1.0 implementation of a RAG pipeline.
#
# Using the VectorStore we created last time (with HuggingFace `all-MiniLM-L6-v2`)

# %%
# !pip install langchain-ollama langchain-anthropic
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.0.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.3.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\ai\.venv\lib\site-packages (from langchain-ollama) (1.2.11)
# Collecting ollama<1.0.0,>=0.6.0 (from langchain-ollama)
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.5)
# Requirement already satisfied: packaging>=23.2.0 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\ai\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\ai\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\ai\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\ai\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in d:\ai\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\ai\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\ai\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.23.0)
# Requirement already satisfied: anyio in d:\ai\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.9.0)
# Requirement already satisfied: certifi in d:\ai\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in d:\ai\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in d:\ai\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\ai\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\ai\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\ai\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\ai\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai\.venv\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai\.venv\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.5.0)
# Collecting anthropic<1.0.0,>=0.78.0 (from langchain-anthropic)
#   Downloading anthropic-0.79.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\ai\.venv\lib\site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (1.9.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic<1.0.0,>=0.78.0->langchain-anthropic)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\ai\.venv\lib\site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (0.10.0)
# Requirement already satisfied: sniffio in d:\ai\.venv\lib\site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (1.3.1)
# Downloading langchain_ollama-1.0.1-py3-none-any.whl (29 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Downloading langchain_anthropic-1.3.3-py3-none-any.whl (46 kB)
# Downloading anthropic-0.79.0-py3-none-any.whl (405 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Installing collected packages: docstring-parser, ollama, anthropic, langchain-ollama, langchain-anthropic
#
#    ---------------------------------------- 0/5 [docstring-parser]
#   Attempting uninstall: ollama
#    ---------------------------------------- 0/5 [docstring-parser]
#     Found existing installation: ollama 0.5.1
#    ---------------------------------------- 0/5 [docstring-parser]
#     Uninstalling ollama-0.5.1:
#    ---------------------------------------- 0/5 [docstring-parser]
#       Successfully uninstalled ollama-0.5.1
#    ---------------------------------------- 0/5 [docstring-parser]
#    -------- ------------------------------- 1/5 [ollama]
#   Attempting uninstall: anthropic
#    -------- ------------------------------- 1/5 [ollama]
#     Found existing installation: anthropic 0.57.1
#    -------- ------------------------------- 1/5 [ollama]
#    ---------------- ----------------------- 2/5 [anthropic]
#     Uninstalling anthropic-0.57.1:
#    ---------------- ----------------------- 2/5 [anthropic]
#       Successfully uninstalled anthropic-0.57.1
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    ---------------- ----------------------- 2/5 [anthropic]
#    -------------------------------- ------- 4/5 [langchain-anthropic]
#    ---------------------------------------- 5/5 [langchain-anthropic]
#
# Successfully installed anthropic-0.79.0 docstring-parser-0.17.0 langchain-anthropic-1.3.3 langchain-ollama-1.0.1 ollama-0.6.1
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

from langchain_ollama import ChatOllama
from langchain_anthropic import ChatAnthropic

from langchain_chroma import Chroma
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_huggingface import HuggingFaceEmbeddings
import gradio as gr

# %%
MODEL = "gpt-4.1-nano"
DB_NAME = "vector_db"
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Connect to Chroma; use Hugging Face all-MiniLM-L6-v2

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#  we can use this, but then our database should be recreated using this
#embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
vectorstore = Chroma(persist_directory=DB_NAME, embedding_function=embeddings)

# %% [markdown]
# ### Set up the 2 key LangChain objects: retriever and llm
#
# #### A sidebar on "temperature":
# - Controls how diverse the output is
# - A temperature of 0 means that the output should be predictable
# - Higher temperature for more variety in answers
#
# Some people describe temperature as being like 'creativity' but that's not quite right
# - It actually controls which tokens get selected during inference
# - temperature=0 means: always select the token with highest probability
# - temperature=1 usually means: a token with 10% probability should be picked 10% of the time
#
# Note: a temperature of 0 doesn't mean outputs will always be reproducible. You also need to set a random seed. We will do that in weeks 6-8. (Even then, it's not always reproducible.)
#
# Note 2: if you want creativity, use the System Prompt!

# %%
retriever = vectorstore.as_retriever()
llm = ChatOpenAI(temperature=0, model_name=MODEL)

# %% [markdown]
# ### These LangChain objects implement the method `invoke()`

# %%
retriever.invoke("Who is Avery?")
# Out:
# [Document(id='8084191c-30e3-425c-8014-34b368f887dd', metadata={'source': 'knowledge-base\\employees\\Avery Lancaster.md', 'doc_type': 'employees'}, page_content="## Other HR Notes\n- **Professional Development**: Avery has actively participated in leadership training programs and industry conferences, representing Insurellm and fostering partnerships.  \n- **Diversity & Inclusion Initiatives**: Avery has championed a commitment to diversity in hiring practices, seeing visible improvements in team representation since 2021.  \n- **Work-Life Balance**: Feedback revealed concerns regarding work-life balance, which Avery has approached by implementing flexible working conditions and ensuring regular check-ins with the team.\n- **Community Engagement**: Avery led community outreach efforts, focusing on financial literacy programs, particularly aimed at underserved populations, improving Insurellm's corporate social responsibility image.  \n\nAvery Lancaster has demonstrated resilience and adaptability throughout her career at Insurellm, positioning the company as a key player in the insurance technology landscape."),
#  Document(id='70d0d768-60d7-46fc-80d8-582c7a2940ad', metadata={'doc_type': 'employees', 'source': 'knowledge-base\\employees\\Avery Lancaster.md'}, page_content='- **2022**: **Satisfactory**  \n  Avery focused on rebuilding team dynamics and addressing employee concerns, leading to overall improvement despite a saturated market.  \n\n- **2023**: **Exceeds Expectations**  \n  Market leadership was regained with innovative approaches to personalized insurance solutions. Avery is now recognized in industry publications as a leading voice in Insurance Tech innovation.'),
#  Document(id='cc0eb735-8c9d-4acc-801f-55030344dff0', metadata={'doc_type': 'employees', 'source': 'knowledge-base\\employees\\Avery Lancaster.md'}, page_content="- **2018**: **Exceeds Expectations**  \n  Under Avery’s pivoted vision, Insurellm launched two new successful products that significantly increased market share.  \n\n- **2019**: **Meets Expectations**  \n  Steady growth, however, some team tensions led to a minor drop in employee morale. Avery recognized the need to enhance company culture.  \n\n- **2020**: **Below Expectations**  \n  The COVID-19 pandemic posed unforeseen operational difficulties. Avery faced criticism for delayed strategy shifts, although efforts were eventually made to stabilize the company.  \n\n- **2021**: **Exceptional**  \n  Avery's decisive transition to remote work and rapid adoption of digital tools led to record-high customer satisfaction levels and increased sales.  \n\n- **2022**: **Satisfactory**  \n  Avery focused on rebuilding team dynamics and addressing employee concerns, leading to overall improvement despite a saturated market."),
#  Document(id='f0df149d-524a-487c-a185-bd3e51a2afc9', metadata={'source': 'knowledge-base\\employees\\Avery Lancaster.md', 'doc_type': 'employees'}, page_content='# Avery Lancaster\n\n## Summary\n- **Date of Birth**: March 15, 1985\n- **Job Title**: Co-Founder & Chief Executive Officer (CEO)\n- **Location**: San Francisco, California\n- **Current Salary**: $225,000  \n\n## Insurellm Career Progression\n- **2015 - Present**: Co-Founder & CEO  \n  Avery Lancaster co-founded Insurellm in 2015 and has since guided the company to its current position as a leading Insurance Tech provider. Avery is known for her innovative leadership strategies and risk management expertise that have catapulted the company into the mainstream insurance market.  \n\n- **2013 - 2015**: Senior Product Manager at Innovate Insurance Solutions  \n  Before launching Insurellm, Avery was a leading Senior Product Manager at Innovate Insurance Solutions, where she developed groundbreaking insurance products aimed at the tech sector.')]

# %%
llm.invoke("Who is Avery?")
# Out:
# AIMessage(content='Avery is a name that can refer to various individuals, characters, or entities depending on the context. Could you please provide more details or specify which Avery you are referring to?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 11, 'total_tokens': 47, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_336de151a4', 'id': 'chatcmpl-D8lvO2G2TX83xSCtC8Fygb3mW7Buc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c56d3-58bd-7c02-8402-1fd9ca361754-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 36, 'total_tokens': 47, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## Time to put this together!

# %%
SYSTEM_PROMPT_TEMPLATE = """
You are a knowledgeable, friendly assistant representing the company Insurellm.
You are chatting with a user about Insurellm.
If relevant, use the given context to answer any question.
If you don't know the answer, say so.
Context:
{context}
"""

# %%
def answer_question(question: str, history):
    docs = retriever.invoke(question)
    context = "\n\n".join(doc.page_content for doc in docs)
    system_prompt = SYSTEM_PROMPT_TEMPLATE.format(context=context)
    response = llm.invoke([SystemMessage(content=system_prompt), HumanMessage(content=question)])
    return response.content

# %%
answer_question("Who is Averi Lancaster?", [])
# Out:
# 'It seems there might be a typo in the name. Based on the information I have, you might be referring to Avery Lancaster. She is the Co-Founder and Chief Executive Officer (CEO) of Insurellm, based in San Francisco, California. Avery has been with the company since 2015 and has played a key role in guiding Insurellm to become a leading Insurance Tech provider. If you meant someone else or need more details, please let me know!'

# %% [markdown]
# ## What could possibly come next? 😂

# %%
gr.ChatInterface(answer_question).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Admit it - you thought RAG would be more complicated than that!!
