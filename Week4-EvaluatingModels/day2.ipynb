# %% [markdown]
# ### Navigating AI Leaderboards: Artificial Analysis, Hugging Face & more
# - Artificial Analysis (by THE leaderboard) - intelligence, cost, speed etc...
#     - https://artificialanalysis.ai/
# - Vellum - includes API cost and context window side by side
#     - https://www.vellum.ai/llm-leaderboard?utm_source=direct&utm_medium=none
# - Scale.com (by SEAL leaderboards)
#     - https://scale.com/leaderboard
# - Hugging Face - open source leaderboards
#     - https://huggingface.co/spaces?q=leaderboard
# - LiveBench - contamination-free (data set leaking)
#     - https://livebench.ai/#/

# %% [markdown]
# ### The arena
# - https://arena.ai/
# - compare frontier and open-source models
# - blind human evals based on head-to-head comparison
# - LLMs are measured with an ELO-style score rating

# %% [markdown]
# ### Comercial Use Cases
# - Automate, then Augment, the Differentiate
# - ChatGPT Wrapper: Duolingo, Copilots
# - Specialized:
#     - Harvey: Law
#     - nebula.io: Talent carrer and jobs
#     - Khanmigo: Khan Academy
#     - Salesforce Health: health care, docktor notes, clinical meetings
#     - Palantir: data platform
#
#     - having your own dataset you make you able to build an specialized AI that other people can't
#
# - Agentic
#     - Claude Code
#     - OpenAI Codex
#     - OpenAI Agent
